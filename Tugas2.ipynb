# %%
print("m rizal fauzi")
print("nim =0110223046")
print("kelas=ti01")
print("alamat=jl.sukajaya")

print()

print("nama= muhammad fahmi ramadhan")
print("nim = 0110223049")
print("kelas=ti01")
print("alamat= gunung putri bogor")

print()

print(5+4)
print(10/7)
# Out:
# m rizal fauzi
# nim =0110223046
# kelas=ti01
# alamat=jl.sukajaya
#
# nama= muhammad fahmi ramadhan
# nim = 0110223049
# kelas=ti01
# alamat= gunung putri bogor
#
# 9
# 1.4285714285714286
